# %%
library(OmnipathR)
# library(nichenetr)
library(tidyverse)
library(dplyr)
library(VennDiagram)
library(ggplot2)
library(utils)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.5.0
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Loading required package: grid
#
# Loading required package: futile.logger

# %%
complete <- read.csv("L_R_OmniPathFull.csv")

# %%
complete[grep("ligand", complete$Receptor.Name), ]
# Out:
#      Pair.Name          Ligand    Ligand.Name
# 15   ACVR2B_DLK1        ACVR2B    activin A receptor type 2B
# 1080 CD274_PDCD1LG2     CD274     CD274 molecule
# 1132 CD46_JAG1          CD46      CD46 molecule
# 1234 CEACAM4_PDCD1LG2   CEACAM4   CEA cell adhesion molecule 4
# 2349 ERBB4_DLK1         ERBB4     erb-b2 receptor tyrosine kinase 4
# 2439 FCAR_PDCD1LG2      FCAR      Fc alpha receptor
# 3425 ICAM5_PDCD1LG2     ICAM5     intercellular adhesion molecule 5
# 3427 ICOS_ICOSLG        ICOS      inducible T cell costimulator
# 3583 IL15_DLK1          IL15      interleukin 15
# 3664 IL2_DLK1           IL2       interleukin 2
# 3735 IL4_DLK1           IL4       interleukin 4
# 3764 IL7_DLK1           IL7       interleukin 7
# 3768 IL9_DLK1           IL9       interleukin 9
# 4011 KRTAP4-12_DLK2     KRTAP4-12 keratin associated protein 4-12
# 4646 MUSK_DLL1          MUSK      muscle associated receptor tyrosine kinase
# ...

# %%
complete
# Out:
#      Pair.Name         Ligand
# 1    A2M_LRP1          A2M
# 2    AANAT_MTNR1A      AANAT
# 3    AANAT_MTNR1B      AANAT
# 4    ABCA1_SHANK1      ABCA1
# 5    ACE_AGTR2         ACE
# 6    ACE_BDKRB2        ACE
# 7    ACE2_SLC6A19      ACE2
# 8    ACE2_TIGIT        ACE2
# 9    ACKR1_CCR5        ACKR1
# 10   ACKR3_CXCR4       ACKR3
# 11   ACP4_VSTM2B       ACP4
# 12   ACTR2_ADRB2       ACTR2
# 13   ACTR2_LDLR        ACTR2
# 14   ACTR2_LRP2        ACTR2
# 15   ACVR2B_DLK1       ACVR2B
# 16   ACVRL1_ACVR2A     ACVRL1
# 17   ACVRL1_CDH5       ACVRL1
# 18   ACVRL1_TGFBR1     ACVRL1
# 19   ADA_DPP4          ADA
# 20   ADAM10_AXL        ADAM10
# 21   ADAM10_CADM1      ADAM10
# 22   ADAM10_CD44       ADAM10
# 23   ADAM10_CLDN11     ADAM10
# 24   ADAM10_DDR1       ADAM10
# 25   ADAM10_EFNA3      ADAM10
# 26   ADAM10_EPHA3      ADAM10
# 27   ADAM10_GPNMB      ADAM10
# 28   ADAM10_IL6R       ADAM10
# 29   ADAM10_MET        ADAM10
# 30   ADAM10_NOTCH1     ADAM10
# ⋮    ⋮                 ⋮
# ...
